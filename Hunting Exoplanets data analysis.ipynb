# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np

# %%
exotrain_df=pd.read_csv('https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/kepler-exoplanets-dataset/exoTrain.csv')
exotrain_df.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
#
#     FLUX.8  FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89  ...     -78.07    -102.15    -102.15      25.13
# 1   -85.33  -83.97  ...      -3.28     -32.21     -32.21     -24.89
# 2   486.39  436.56  ...     -71.69      13.31      13.31     -29.89
# 3   311.31  312.42  ...       5.71      -3.73      -3.73      30.05
# 4 -1022.71 -989.57  ...    -594.37    -401.66    -401.66    -357.24
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
exotest_df=pd.read_csv('https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/kepler-exoplanets-dataset/exoTest.csv')
exotest_df.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6   FLUX.7  \
# 0      2   119.88   100.21    86.46    48.68    46.12    39.39    18.57
# 1      2  5736.59  5699.98  5717.16  5692.73  5663.83  5631.16  5626.39
# 2      2   844.48   817.49   770.07   675.01   605.52   499.45   440.77
# 3      2  -826.00  -827.31  -846.12  -836.03  -745.50  -784.69  -791.22
# 4      2   -39.57   -15.88    -9.16    -6.37   -16.13   -24.05    -0.90
#
#     FLUX.8   FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0     6.98     6.63  ...      14.52      19.29      14.44      -1.62
# 1  5569.47  5550.44  ...    -581.91    -984.09   -1230.89   -1600.45
# 2   362.95   207.27  ...      17.82     -51.66     -48.29     -59.99
# 3  -746.50  -709.53  ...     122.34      93.03      93.03      68.81
# 4   -45.20    -5.04  ...     -37.87     -61.85     -27.15     -21.18
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
exotrain_df.shape
exotest_df.shape
# Out:
# (570, 3198)

# %%
exotest_df.isnull()
# Out:
#      LABEL  FLUX.1  FLUX.2  FLUX.3  FLUX.4  FLUX.5  FLUX.6  FLUX.7  FLUX.8  \
# 0    False   False   False   False   False   False   False   False   False
# 1    False   False   False   False   False   False   False   False   False
# 2    False   False   False   False   False   False   False   False   False
# 3    False   False   False   False   False   False   False   False   False
# 4    False   False   False   False   False   False   False   False   False
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 565  False   False   False   False   False   False   False   False   False
# 566  False   False   False   False   False   False   False   False   False
# 567  False   False   False   False   False   False   False   False   False
# 568  False   False   False   False   False   False   False   False   False
# 569  False   False   False   False   False   False   False   False   False
#
# ...

# %%
exotrain_df.isnull().sum()
# Out:
# LABEL        0
# FLUX.1       0
# FLUX.2       0
# FLUX.3       0
# FLUX.4       0
#             ..
# FLUX.3193    0
# FLUX.3194    0
# FLUX.3195    0
# FLUX.3196    0
# FLUX.3197    0
# Length: 3198, dtype: int64

# %%
exotrain_df.columns
# Out:
# Index(['LABEL', 'FLUX.1', 'FLUX.2', 'FLUX.3', 'FLUX.4', 'FLUX.5', 'FLUX.6',
#        'FLUX.7', 'FLUX.8', 'FLUX.9',
#        ...
#        'FLUX.3188', 'FLUX.3189', 'FLUX.3190', 'FLUX.3191', 'FLUX.3192',
#        'FLUX.3193', 'FLUX.3194', 'FLUX.3195', 'FLUX.3196', 'FLUX.3197'],
#       dtype='object', length=3198)

# %%
exotrain_df['FLUX.1']
# Out:
# 0         93.85
# 1        -38.88
# 2        532.64
# 3        326.52
# 4      -1107.21
#          ...
# 5082     -91.91
# 5083     989.75
# 5084     273.39
# 5085       3.82
# 5086     323.28
# Name: FLUX.1, Length: 5087, dtype: float64

# %%
num_missing_value=0
for column in exotrain_df:
    for item in exotrain_df[column].isnull():
        if item==False:
            num_missing_value+=1
num_missing_value
# Out:
# 16268226

# %%
star_0=exotrain_df.iloc[0,:]
star_0
# Out:
# LABEL         2.00
# FLUX.1       93.85
# FLUX.2       83.81
# FLUX.3       20.10
# FLUX.4      -26.98
#              ...
# FLUX.3193    92.54
# FLUX.3194    39.32
# FLUX.3195    61.42
# FLUX.3196     5.08
# FLUX.3197   -39.54
# Name: 0, Length: 3198, dtype: float64

# %%
star_1=exotrain_df.iloc[1,:]
star_1
# Out:
# LABEL         2.00
# FLUX.1      -38.88
# FLUX.2      -33.83
# FLUX.3      -58.54
# FLUX.4      -40.09
#              ...
# FLUX.3193     0.76
# FLUX.3194   -11.70
# FLUX.3195     6.46
# FLUX.3196    16.00
# FLUX.3197    19.93
# Name: 1, Length: 3198, dtype: float64

# %%
star_2=exotrain_df.iloc[2,:]
star_2
# Out:
# LABEL          2.00
# FLUX.1       532.64
# FLUX.2       535.92
# FLUX.3       513.73
# FLUX.4       496.92
#               ...
# FLUX.3193      5.06
# FLUX.3194    -11.80
# FLUX.3195    -28.91
# FLUX.3196    -70.02
# FLUX.3197    -96.67
# Name: 2, Length: 3198, dtype: float64

# %%
exotrain_df.tail()
# Out:
#       LABEL  FLUX.1  FLUX.2  FLUX.3  FLUX.4  FLUX.5  FLUX.6  FLUX.7  FLUX.8  \
# 5082      1  -91.91  -92.97  -78.76  -97.33  -68.00  -68.24  -75.48  -49.25
# 5083      1  989.75  891.01  908.53  851.83  755.11  615.78  595.77  458.87
# 5084      1  273.39  278.00  261.73  236.99  280.73  264.90  252.92  254.88
# 5085      1    3.82    2.09   -3.29   -2.88    1.66   -0.75    3.85   -0.03
# 5086      1  323.28  306.36  293.16  287.67  249.89  218.30  188.86  178.93
#
#       FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  FLUX.3192  \
# 5082  -30.92  ...     139.95     147.26     156.95     155.64     156.36
# 5083  492.84  ...     -26.50      -4.84     -76.30     -37.84    -153.83
# 5084  237.60  ...     -26.82     -53.89     -48.71      30.99      15.96
# 5085    3.28  ...      10.86      -3.23      -5.10      -4.61      -9.82
# 5086  118.93  ...      71.19       0.97      55.20      -1.63      -5.50
#
#       FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
star_5086=exotrain_df.iloc[5086,:]
star_5086
# Out:
# LABEL          1.00
# FLUX.1       323.28
# FLUX.2       306.36
# FLUX.3       293.16
# FLUX.4       287.67
#               ...
# FLUX.3193    -25.33
# FLUX.3194    -41.31
# FLUX.3195    -16.72
# FLUX.3196    -14.09
# FLUX.3197     27.82
# Name: 5086, Length: 3198, dtype: float64

# %%
star_5085=exotrain_df.iloc[5085,:]
star_5085
# Out:
# LABEL         1.00
# FLUX.1        3.82
# FLUX.2        2.09
# FLUX.3       -3.29
# FLUX.4       -2.88
#              ...
# FLUX.3193    -1.50
# FLUX.3194    -4.65
# FLUX.3195   -14.55
# FLUX.3196    -6.41
# FLUX.3197    -2.55
# Name: 5085, Length: 3198, dtype: float64

# %%
star_5084=exotrain_df.iloc[5084,:]
star_5084
# Out:
# LABEL          1.00
# FLUX.1       273.39
# FLUX.2       278.00
# FLUX.3       261.73
# FLUX.4       236.99
#               ...
# FLUX.3193     -3.47
# FLUX.3194     65.73
# FLUX.3195     88.42
# FLUX.3196     79.07
# FLUX.3197     79.43
# Name: 5084, Length: 3198, dtype: float64

# %%
plt.figure(figsize=(15,8))
x_value_star_0=np.arange(1,3198)
y_value_star_0=star_0[1:]
plt.scatter(x_value_star_0,y_value_star_0)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(x_value_star_0,y_value_star_0)
plt.show()

# %%
plt.figure(figsize=(15,8))
x_value_star_1=np.arange(1,3198)
y_value_star_1=star_1[1:]
plt.scatter(x_value_star_1,y_value_star_1)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(x_value_star_1,y_value_star_1)
plt.show()

# %%
plt.figure(figsize=(15,8))
x_value_star_2=np.arange(1,3198)
y_value_star_2=star_2[1:]
plt.scatter(x_value_star_2,y_value_star_2)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(x_value_star_2,y_value_star_2)
plt.show()

# %%
plt.figure(figsize=(15,8))
x_value_star_5084=np.arange(1,3198)
y_value_star_5084=star_5084[1:]
plt.scatter(x_value_star_5084,y_value_star_5084)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(x_value_star_5084,y_value_star_5084)
plt.show()

# %%
plt.figure(figsize=(15,8))
x_value_star_5085=np.arange(1,3198)
y_value_star_5085=star_5085[1:]
plt.scatter(x_value_star_5085,y_value_star_5085)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(x_value_star_5085,y_value_star_5085)
plt.show()

# %%
plt.figure(figsize=(15,8))
x_value_star_5086=np.arange(1,3198)
y_value_star_5086=star_5086[1:]
plt.scatter(x_value_star_5086,y_value_star_5086)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(x_value_star_5086,y_value_star_5086)
plt.show()
